# %%
import rdkit 
from rdkit import Chem 
from rdkit.Chem import PandasTools
from utils import *

# %%
dataframe = PandasTools.LoadSDF('data/enamine_discovery_diversity_set_10k.sdf', molColName='ROMol')
exist_desc = {'MW': [200, 300], 'HBA':[1, 4], 'ClogP': [-1, 2], 'logS': [-3, 0], 'TPSA': [20, 70]}
dataframe.head()
# Out:
#     Catalog ID       MW MW (desalted)   ClogP    logS HBD HBA   TPSA RotBonds  \
# 0  Z2996115794  341.426       341.426    0.97   -2.35   2   4  91.65        3
# 1  Z2996180243  344.337       344.337   1.204  -3.276   1   5  86.11        3
# 2  Z2997740134  320.294       320.294  -0.086  -3.112   1   3  67.23        2
# 3  Z3000832898  325.268       325.268   1.357  -2.858   1   4  78.95        2
# 4  Z3016311397  326.411       326.411    1.99  -2.725   1   4  75.71        3
#
#   ID                                          ROMol
# 0     <rdkit.Chem.rdchem.Mol object at 0x2b8864a50>
# 1     <rdkit.Chem.rdchem.Mol object at 0x2b8864f20>
# 2     <rdkit.Chem.rdchem.Mol object at 0x2b8864f90>
# 3     <rdkit.Chem.rdchem.Mol object at 0x2b8865070>
# 4     <rdkit.Chem.rdchem.Mol object at 0x2b88650e0>

# %%
molecular_radar_plot(dataframe, exist_desc, scale=5)
